# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("Store Sales.csv")

# %%
df.sample(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1398           FDT12        6.215          Regular         0.049580
# 4987           FDR48       11.650          Low Fat         0.220111
# 4328           FDL24       10.300          Regular         0.024947
# 458            DRB48          NaN          Regular         0.024733
# 538            FDO04       16.600          Low Fat         0.026537
# 1819           FDP20       19.850          Low Fat         0.045669
# 4700           FDU19        8.770          Regular         0.047036
# 247            FDU44       12.150          Regular         0.058415
# 2783           NCI55       18.600          Low Fat         0.012679
# 1431           DRB13        6.115          Regular         0.007084
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1398           Baking Goods  227.4062            OUT013
# 4987           Baking Goods  153.0024            OUT010
# 4328           Baking Goods  172.3422            OUT045
# 458             Soft Drinks   40.2822            OUT027
# 538            Frozen Foods   57.2614            OUT046
# 1819  Fruits and Vegetables  126.4020            OUT046
# 4700  Fruits and Vegetables  170.5422            OUT017
# 247   Fruits and Vegetables  163.4552            OUT035
# 2783              Household  120.9414            OUT045
# 1431            Soft Drinks  191.1530            OUT017
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1398                       1987        High               Tier 3
# 4987                       1998         NaN               Tier 3
# 4328                       2002         NaN               Tier 2
# 458                        1985      Medium               Tier 3
# 538                        1997       Small               Tier 1
# 1819                       1997       Small               Tier 1
# 4700                       2007         NaN               Tier 2
# 247                        2004       Small               Tier 2
# 2783                       2002         NaN               Tier 2
# 1431                       2007         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 1398  Supermarket Type1          5191.2426
# 4987      Grocery Store           455.4072
# 4328  Supermarket Type1          5690.5926
# 458   Supermarket Type3          1296.3126
# 538   Supermarket Type1          1049.9666
# 1819  Supermarket Type1          1012.0160
# 4700  Supermarket Type1          2759.0752
# 247   Supermarket Type1           974.7312
# 2783  Supermarket Type1          2680.5108
# 1431  Supermarket Type1          3415.5540

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
print("\nTotal Empty cells by columns :\n{}".format(df.isna().sum()),"\n\n")
# Out:
# Total Empty cells by columns :
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isna())
plt.title("No of Missing data present in our columns")
plt.show()

# %%
df["Item_Weight"].value_counts()
# Out:
# Item_Weight
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: count, Length: 415, dtype: int64

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df['Item_Weight'].median()
# Out:
# 12.6

# %%
df['Item_Weight'].mean()
# Out:
# 12.857645184135976

# %%
df['Item_Weight'].mode()
# Out:
# 0    12.15
# Name: Item_Weight, dtype: float64

# %%
sns.displot(df['Item_Weight'])
# Out:
# C:\Users\hp1\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Item_Weight'].fillna(df['Item_Weight'].mean(), inplace=True)

# %%
sns.displot(df['Item_Weight'])
# Out:
# C:\Users\hp1\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['Outlet_Size'])
# Out:
# C:\Users\hp1\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df["Outlet_Size"].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isna())
plt.title("No of Missing data present in our columns")
plt.show()

# %%
df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0],inplace=True)

# %%
df["Outlet_Size"].value_counts()
# Out:
# Outlet_Size
# Medium    5203
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isna())
plt.title("No of Missing data present in our columns")
plt.show()

# %%
df["Item_Fat_Content"].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Item_Fat_Content', palette='Set2')
plt.title('Item Fat Content Distribution')
plt.show()

# %%
df.replace({'Item_Fat_Content': {'low fat':'Low Fat','LF':'Low Fat', 'reg':'Regular'}}, inplace=True)

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Item_Fat_Content', palette='Set2')
plt.title('Item Fat Content Distribution')
plt.show()

# %%
df['Item_Type'].value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Item_Type', palette='Set2')
plt.title('Item Type Distribution')
plt.show()

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# Outlet_Identifier
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Outlet_Identifier', palette='Set2')
plt.title('Outlet Identifier Distribution')
plt.show()

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Outlet_Location_Type', palette='Set2')
plt.title('Outlet Location Type Distribution')
plt.show()

# %%
df['Outlet_Type'].value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Outlet_Type', palette='Set2')
plt.title('Outlet Type Distribution')
plt.show()

# %%
sns.displot(df["Item_Visibility"])

plt.title('Item Visibility')
plt.xlabel('Item_Visibility')
plt.ylabel('No. of observations')
# Out:
# C:\Users\hp1\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(4.944444444444445, 0.5, 'No. of observations')

# %%
sns.displot(df["Item_MRP"])

plt.title('Item MRP')
plt.xlabel('Item_MRP')
plt.ylabel('No. of observations')
# Out:
# C:\Users\hp1\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(4.944444444444445, 0.5, 'No. of observations')

# %%
sns.displot(df["Item_Outlet_Sales"])

plt.title('Item_Outlet_Sales')
plt.xlabel('Item Outlet sales')
plt.ylabel('No. of observations')
# Out:
# C:\Users\hp1\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(4.944444444444445, 0.5, 'No. of observations')

# %%
outlet_size_sales = df.groupby('Outlet_Size')['Item_Outlet_Sales'].sum()
plt.figure(figsize=(8, 6))
sns.barplot(x=outlet_size_sales.index, y=outlet_size_sales.values, palette='magma')
plt.title('Sales by Outlet Size')
plt.xlabel('Outlet Size')
plt.ylabel('Total Sales')
plt.show()

# %%
df["Outlet_Type"].value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Item_MRP', y='Item_Outlet_Sales', hue='Outlet_Type', palette='Set2')
plt.title('Item MRP vs Sales')
plt.xlabel('Item MRP')
plt.ylabel('Item Outlet Sales')
plt.show()

# %%
outlet_year_sales = df.groupby('Outlet_Establishment_Year')['Item_Outlet_Sales'].sum()
plt.figure(figsize=(10, 6))
sns.lineplot(x=outlet_year_sales.index, y=outlet_year_sales.values, marker='o', color='b')
plt.title('Sales by Outlet Establishment Year')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Total Sales')
plt.show()

# %%
item_sales = df.groupby('Item_Type')['Item_Outlet_Sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(12, 8))
sns.barplot(x=item_sales.values, y=item_sales.index, palette='coolwarm')
plt.title('Total Sales by Item Type')
plt.xlabel('Total Sales')
plt.ylabel('Item Type')
plt.show()
